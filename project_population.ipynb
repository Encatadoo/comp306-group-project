# %%
import mysql.connector
import matplotlib.pyplot as plt
import csv

# %matplotlib inline

# %%
db_connection = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Ba17252134364."
)
print(db_connection)

# %%
# creating database_cursor to perform SQL operation
db_cursor = db_connection.cursor(buffered=True)

# %%
db_cursor.execute("USE project")
db_cursor.execute("show tables")
for db in db_cursor:
    print(db)
# Out:
# ('accountassets',)
# ('accounts',)
# ('assets',)
# ('checking_account',)
# ('credit_account',)
# ('customer',)
# ('department',)
# ('department_location',)
# ('employee',)
# ('individual_c',)
# ('insitutional_c',)
# ('investment_account',)
# ('loan',)
# ('r_transaction',)
# ('saving_account',)
# ('t_transaction',)
# ('title',)
# ('transactions',)

# %%
def populate_table(db_connection, db_cursor, insert_query, file_path):
    
    with open(file_path, mode='r') as csv_data:
        reader = csv.reader(csv_data, delimiter=';')
        csv_data_list = list(reader)
        for row in csv_data_list[1:]:
            row = tuple(map(lambda x: None if x == "" else x, row[0].split(',')))
            print(row)
            db_cursor.execute(insert_query, row)
        
    db_connection.commit()

# %%
insert_employee = (
    "INSERT INTO EMPLOYEE(emp_id, Name, Birthdate, Age, Gender, Dept_ID, mng_id, Salary, PerfScore, EmpSatisfaction, EngagementSurvey) "
    "VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
)
populate_table(db_connection, db_cursor, insert_employee, "excels/Employee.csv")

# %%
insert_dept = (
    "INSERT INTO DEPARTMENT(Dept_ID, mng_id, D_Name) "
    "VALUES (%s, %s, %s)"
)
populate_table(db_connection, db_cursor, insert_dept, "excels/Department.csv")
# Out:
# ('1', '10134', 'Admin Offices')
# ('4', '10010', 'Software Engineering')
# ('5', '10131', 'HR')
# ('6', '10272', 'Sales')
# ('3', '10090', 'Business Analyst')
# ('2', '10089', 'Executive Office')

# %%
insert_cust = (
    "INSERT INTO CUSTOMER(C_ID, C_name, income, years_of_credit_hist, credit_score) "
    "VALUES (%s, %s, %s, %s, %s)"
)
populate_table(db_connection, db_cursor, insert_cust, "excels/Customer.csv")
# Out:
# ('13500', 'Aleph HILL', '911430', '25', '748')
# ('13501', 'Robbie FLORES', '904058', '33', '709')
# ('13502', 'Yanel GREEN', '1012510', '32', '724')
# ('13503', 'Timea MARTIN', '950969', '16', '714')
# ('13504', 'Ralphy ADAMS', '766384', '44', '714')
# ('13505', 'Lilian NELSON', '1292646', '1', '729')
# ('13506', 'Savage BAKER', '1256128', '5', '722')
# ('13507', 'Aazan HALL', '1317707', '22', '662')
# ('13508', 'Jarrick RIVERA', '1494939', '14', '738')
# ('13509', 'Lionel CAMPBELL', '422256', '37', '675')
# ('13510', 'Kenasia MITCHELL', '1264127', '22', '740')
# ('13511', 'Sareena CARTER', '1006677', '32', '717')
# ('13512', 'Masih ROBERTS', '2371200', '22', '717')
# ('13513', 'Madylan GOMEZ', '1390648', '4', '701')
# ('13514', 'Kasch PHILLIPS', '1532407', '49', '700')
# ('13515', 'Rylei EVANS', '555788', '1', '723')
# ('13516', 'Shiya TURNER', '1488080', '14', '692')
# ('13517', 'Paxtyn DIAZ', '1557848', '29', '7330')
# ('13518', 'Demariah PARKER', '2641760', '16', '692')
# ...

# %%
insert_loan = (
    "INSERT INTO LOAN(loan_id, emp_id, c_id, loan_amount) "
    "VALUES (%s, %s, %s, %s)"
)
populate_table(db_connection, db_cursor, insert_loan, "excels/Loan.csv")
# Out:
# ('1', '10030', '13500', '153186')
# ('2', '10030', '13501', '174460')
# ('3', '10030', '13502', '315634')
# ('4', '10030', '13503', '47498')
# ('5', '10030', '13504', '99999999')
# ('6', '10030', '13505', '607376')
# ('7', '10030', '13506', '143198')
# ('8', '10030', '13507', '403876')
# ('9', '10030', '13508', '638638')
# ('10', '10030', '13509', '111122')
# ('11', '10030', '13510', '490578')
# ('12', '10030', '13511', '124410')
# ('13', '10030', '13512', '386584')
# ('14', '10030', '13513', '334466')
# ('15', '10030', '13514', '335082')
# ('16', '10030', '13515', '113718')
# ('17', '10030', '13516', '99999999')
# ('18', '10030', '13517', '69894')
# ('19', '10030', '13518', '759308')
# ('20', '10030', '13519', '99999999')
# ('21', '10030', '13520', '215688')
# ('22', '10030', '13521', '99999999')
# ('23', '10030', '13522', '155562')
# ('24', '10030', '13523', '178706')
# ('25', '10099', '13524', '761068')
# ('26', '10099', '13525', '80168')
# ('27', '10099', '13526', '263648')
# ...

# %%
insert_dep_loc = (
    "INSERT INTO DEPARTMENT_LOCATION(Dept_ID, Location) "
    "VALUES (%s, %s)"
)
populate_table(db_connection, db_cursor, insert_dep_loc, "excels/DepartmentLocation.csv")
# Out:
# ('1', 'New York')
# ('4', 'San Diego')
# ('4', 'New York')
# ('5', 'New York')
# ('5', 'San Diego')
# ('6', 'Oregon')
# ('6', 'Boston')
# ('6', 'San Francisco')
# ('6', 'Los Angeles')
# ('6', 'New Jersey')
# ('6', 'Austin')
# ('6', 'Massachusetts')
# ('6', 'Chicago')
# ('6', 'Seattle')
# ('6', 'New Orleans')
# ('6', 'San Diego')
# ('6', 'Miami')
# ('6', 'Atlanta')
# ('6', 'San Antonio')
# ('3', 'New York')
# ('2', 'New York')
# ('2', 'San Diego')

# %%
insert_title = (
    "INSERT INTO TITLE(Emp_id, Title_name, From_date, To_date) "
    "VALUES (%s, %s, %s, %s)"
)
populate_table(db_connection, db_cursor, insert_title, "excels/Title.csv")
# Out:
# ('10089', 'President & CEO', '2004-8-19', None)
# ('10131', 'Dİrector of HR', '2006-5-9', None)
# ('10134', 'Shared Services Manager', '2006-9-25', None)
# ('10010', 'Director of Software Engineering', '2007-12-28', None)
# ('10272', 'Director of Sales', '2008-7-2', None)
# ('10090', 'Director of Business Analyst', '2009-12-10', None)
# ('10238', 'Accountant I', '2005-8-19', None)
# ('10182', 'Administrative Assistant', '2004-1-1', None)
# ('10038', 'Accountant I', '2004-10-21', None)
# ('10039', 'Administrative Assistant', '2010-5-24', None)
# ('10153', 'Administrative Assistant', '2010-8-26', None)
# ('10147', 'Accountant I', '2010-9-29', None)
# ('10259', 'Data Analyst', '2012-8-3', None)
# ('10016', 'Data Analyst', '2012-9-13', None)
# ('10162', 'Data Analyst', '2015-7-3', None)
# ('10149', 'Principal Data Architect', '2016-12-14', None)
# ('10229', 'Data Analyst', '2017-1-23', None)
# ('10178', 'Data Analyst', '2017-8-16', None)
# ...

# %%
insert_instituonal = (
    "INSERT INTO INSITUTIONAL_C(Cust_ID, Cust_type, Get_consultant) "
    "VALUES (%s, %s, %s)"
)
populate_table(db_connection, db_cursor, insert_instituonal, "excels/Institutional Customer.csv")
# Out:
# ('15001', 'SME', 'FALSE')
# ('15002', 'SME', 'TRUE')
# ('15003', 'SME', 'FALSE')
# ('15004', 'SME', 'FALSE')
# ('15005', 'SME', 'TRUE')
# ('15006', 'SME', 'FALSE')
# ('15007', 'SME', 'FALSE')
# ('15008', 'SME', 'FALSE')
# ('15009', 'SME', 'FALSE')
# ('15010', 'SME', 'TRUE')
# ('15011', 'SME', 'FALSE')
# ('15012', 'SME', 'FALSE')
# ('15013', 'SME', 'FALSE')
# ('15014', 'SME', 'FALSE')
# ('15015', 'SME', 'FALSE')
# ('15016', 'SME', 'FALSE')
# ('15017', 'SME', 'TRUE')
# ('15018', 'SME', 'FALSE')
# ('15019', 'SME', 'FALSE')
# ('15020', 'SME', 'FALSE')
# ('15021', 'SME', 'TRUE')
# ('15022', 'SME', 'FALSE')
# ('15023', 'SME', 'TRUE')
# ('15024', 'SME', 'FALSE')
# ('15025', 'SME', 'FALSE')
# ('15026', 'SME', 'FALSE')
# ('15027', 'SME', 'FALSE')
# ('15028', 'SME', 'TRUE')
# ('15029', 'SME', 'FALSE')
# ('15030', 'SME', 'FALSE')
# ('15031', 'SME', 'FALSE')
# ('15032', 'SME', 'FALSE')
# ('15033', 'SME', 'TRUE')
# ('15034', 'SME', 'FALSE')
# ('15035', 'SME', 'FALSE')
# ('15036', 'SME', 'FALSE')
# ...

# %%
insert_individual = (
    "INSERT INTO INDIVIDUAL_C(Cust_ID, year_in_current_job, home_ownership) "
    "VALUES (%s, %s, %s)"
)
populate_table(db_connection, db_cursor, insert_individual, "excels/Individual Customer.csv")
# Out:
# ('14558', '2 years', 'Home Mortgage')
# ('14258', 'n/a', 'Home Mortgage')
# ('13696', 'n/a', 'Home Mortgage')
# ('13740', 'n/a', 'Own Home')
# ('14412', '10+ years', 'Home Mortgage')
# ('13622', '10+ years', 'Rent')
# ('13886', '9 years', 'Rent')
# ('14328', '2 years', 'Home Mortgage')
# ('13503', '10+ years', 'Rent')
# ('13764', '10+ years', 'Own Home')
# ('14128', 'n/a', 'Rent')
# ('13997', 'n/a', 'Rent')
# ('13598', '10+ years', 'Home Mortgage')
# ('13582', '6 years', 'Rent')
# ('14260', '5 years', 'Rent')
# ('14004', '2 years', 'Home Mortgage')
# ('14320', '10+ years', 'Own Home')
# ('13664', '10+ years', 'Home Mortgage')
# ('14368', '8 years', 'Own Home')
# ('13515', 'n/a', 'Own Home')
# ('14126', '2 years', 'Rent')
# ('13975', '< 1 year', 'Rent')
# ('13580', '2 years', 'Home Mortgage')
# ('14399', '8 years', 'Rent')
# ('14062', '5 years', 'Home Mortgage')
# ('14221', '2 years', 'Home Mortgage')
# ('14101', '1 year', 'Rent')
# ('13548', '10+ years', 'Home Mortgage')
# ...

# %%
insert_account = (
    "INSERT INTO ACCOUNTS(A_ID, C_ID) "
    "VALUES (%s, %s)"
)
populate_table(db_connection, db_cursor, insert_account, "excels/Account.csv")
# Out:
# ('1', '13704')
# ('2', '14374')
# ('3', '14177')
# ('4', '14426')
# ('5', '13542')
# ('6', '13658')
# ('7', '13870')
# ('8', '13678')
# ('9', '13522')
# ('10', '13680')
# ('11', '13764')
# ('12', '14085')
# ('13', '13859')
# ('14', '14303')
# ('15', '13506')
# ('16', '13879')
# ('17', '13962')
# ('18', '14389')
# ('19', '13981')
# ('20', '13633')
# ('21', '14526')
# ('22', '14558')
# ('23', '13925')
# ('24', '14340')
# ('25', '14451')
# ('26', '14101')
# ('27', '13650')
# ('28', '13637')
# ('29', '13942')
# ('30', '13914')
# ('31', '14478')
# ('32', '13687')
# ('33', '14262')
# ('34', '14080')
# ('35', '14167')
# ('36', '14249')
# ('37', '13847')
# ('38', '13816')
# ('39', '14409')
# ('40', '13957')
# ('41', '14381')
# ('42', '14369')
# ('43', '13750')
# ('44', '13660')
# ('45', '14078')
# ('46', '14334')
# ('47', '14123')
# ('48', '14193')
# ('49', '14221')
# ('50', '13811')
# ('51', '14501')
# ('52', '14061')
# ('53', '14456')
# ('54', '13547')
# ('55', '14295')
# ('56', '13924')
# ...

# %%
insert_creditaccount = (
    "INSERT INTO CREDIT_ACCOUNT(A_ID, Lim, Old_debt, Interest_rate, Fee) "
    "VALUES (%s, %s, %s, %s, %s)"
)
populate_table(db_connection, db_cursor, insert_creditaccount, "excels/Credit Account.csv")
# Out:
# ('900', '18405', '0', '5', '156')
# ('901', '61112', '163042', '6', '215')
# ('902', '85855', '0', '3', '116')
# ('903', '91535', '0', '5', '157')
# ('904', '66171', '0', '4', '146')
# ('905', '19119', '51846', '9', '276')
# ('906', '13474', '0', '1', '153')
# ('907', '9459', '4741', '9', '247')
# ('908', '49868', '141658', '5', '244')
# ('909', '16611', '68775', '6', '276')
# ('910', '7010', '13009', '7', '290')
# ('911', '76387', '104972', '6', '236')
# ('912', '37393', '0', '4', '153')
# ('913', '61145', '0', '5', '150')
# ('914', '96525', '0', '2', '114')
# ('915', '86241', '332511', '7', '207')
# ('916', '65759', '0', '2', '127')
# ('917', '18512', '0', '5', '121')
# ('918', '67267', '0', '2', '105')
# ('919', '82948', '209827', '7', '266')
# ('920', '7905', '0', '1', '111')
# ('921', '29727', '34713', '7', '253')
# ('922', '88090', '0', '1', '140')
# ('923', '77957', '55550', '5', '216')
# ('924', '81290', '0', '2', '174')
# ('925', '19999', '0', '3', '143')
# ...

# %%
insert_savingaccount = (
    "INSERT INTO SAVING_ACCOUNT(A_ID, Balance, Interest_rate, Currency) "
    "VALUES (%s, %s, %s, %s)"
)
populate_table(db_connection, db_cursor, insert_savingaccount, "excels/Saving Account.csv")
# Out:
# ('1738', '3320', '5', 'TL')
# ('1739', '33918', '6', 'TL')
# ('1740', '60655', '1', 'TL')
# ('1741', '35646', '3', 'TL')
# ('1742', '47811', '6', 'TL')
# ('1743', '95702', '2', 'TL')
# ('1744', '85228', '2', 'TL')
# ('1745', '41280', '6', 'TL')
# ('1746', '92762', '1', 'TL')
# ('1747', '46735', '3', 'TL')
# ('1748', '726402', '1', 'TL')
# ('1749', '41653', '5', 'TL')
# ('1750', '84055', '3', 'TL')
# ('1751', '4994', '2', 'TL')
# ('1752', '80906', '1', 'TL')
# ('1753', '73335', '6', 'TL')
# ('1754', '407967', '5', 'TL')
# ('1755', '34730', '1', 'TL')
# ('1756', '97474', '2', 'TL')
# ('1757', '88761', '6', 'TL')
# ('1758', '90837', '3', 'TL')
# ('1759', '28059', '4', 'TL')
# ('1760', '73620', '5', 'TL')
# ('1761', '36940', '5', 'TL')
# ('1762', '9368', '6', 'TL')
# ('1763', '8704', '2', 'TL')
# ('1764', '92728', '3', 'TL')
# ('1765', '5458403', '3', 'TL')
# ('1766', '37488', '3', 'TL')
# ('1767', '16087', '6', 'TL')
# ('1768', '93198', '5', 'TL')
# ('1769', '89761', '5', 'TL')
# ...

# %%
insert_checkingaccount = (
    "INSERT INTO CHECKING_ACCOUNT(A_ID, Currency, Balance) "
    "VALUES (%s, %s, %s)"
)
populate_table(db_connection, db_cursor, insert_checkingaccount, "excels/Checking Account.csv")
# Out:
# ('1', 'TL', '512995')
# ('2', 'TL', '944471')
# ('3', 'TL', '388639')
# ('4', 'TL', '951446')
# ('5', 'TL', '406375')
# ('6', 'TL', '245306')
# ('7', 'TL', '160174')
# ('8', 'TL', '360573')
# ('9', 'TL', '815869')
# ('10', 'TL', '665819')
# ('11', 'TL', '674710')
# ('12', 'TL', '482872')
# ('13', 'TL', '526936')
# ('14', 'TL', '348243')
# ('15', 'TL', '527506')
# ('16', 'TL', '36398')
# ('17', 'TL', '316702')
# ('18', 'TL', '884500')
# ('19', 'TL', '76261')
# ('20', 'TL', '532007')
# ('21', 'TL', '91584')
# ('22', 'TL', '45633')
# ('23', 'TL', '820022')
# ('24', 'TL', '998955')
# ('25', 'TL', '35227')
# ('26', 'TL', '952273')
# ('27', 'TL', '121836')
# ('28', 'TL', '796614')
# ('29', 'TL', '280550')
# ('30', 'TL', '28323')
# ('31', 'TL', '221110')
# ('32', 'TL', '478048')
# ('33', 'TL', '773067')
# ('34', 'TL', '678695')
# ('35', 'TL', '838063')
# ('36', 'TL', '597928')
# ('37', 'TL', '802182')
# ('38', 'TL', '136805')
# ('39', 'TL', '185371')
# ('40', 'TL', '690285')
# ...

# %%
insert_investmentaccount = (
    "INSERT INTO INVESTMENT_ACCOUNT(A_ID, Balance) "
    "VALUES (%s, %s)"
)
populate_table(db_connection, db_cursor, insert_investmentaccount, "excels/Investment Account.csv")
# Out:
# ('2488', '71039')
# ('2489', '57871')
# ('2490', '9456')
# ('2491', '68997')
# ('2492', '5221')
# ('2493', '9542')
# ('2494', '79764')
# ('2495', '61105')
# ('2496', '1371')
# ('2497', '6745')
# ('2498', '4724482')
# ('2499', '55748')
# ('2500', '12910')
# ('2501', '2378827')
# ('2502', '1795')
# ('2503', '1293')
# ('2504', '75374')
# ('2505', '31449')
# ('2506', '7395')
# ('2507', '15290')
# ('2508', '14522')
# ('2509', '22901')
# ('2510', '88450')
# ('2511', '6679291')
# ('2512', '55078')
# ('2513', '4608150')
# ('2514', '25678')
# ('2515', '15080')
# ('2516', '85152')
# ('2517', '73266')
# ('2518', '83303')
# ('2519', '99421')
# ('2520', '56445')
# ('2521', '69181')
# ('2522', '8736')
# ('2523', '10689')
# ('2524', '25304')
# ('2525', '49536')
# ('2526', '72516')
# ('2527', '8647745')
# ('2528', '64694')
# ('2529', '34567')
# ('2530', '41096')
# ('2531', '9122')
# ('2532', '2196')
# ('2533', '38066')
# ('2534', '100058')
# ('2535', '99894')
# ('2536', '64073')
# ('2537', '51863')
# ...

# %%
insert_asset = (
    "INSERT INTO ASSETS(Asset_ID, A_Code, A_Name, Price) "
    "VALUES (%s, %s, %s, %s)"
)
populate_table(db_connection, db_cursor, insert_asset, "excels/Asset.csv")
# Out:
# ('1', 'TPRAS', 'Tüpraş-Türkiye Petrol Rafinerileri A.Ş.', '96.6')
# ('2', 'KCHOL', 'Koç Holding A.Ş.', '18.89')
# ('3', 'TCELL', 'Turkcell İletişim Hizmetleri A.Ş.', '15.17')
# ('4', 'TTKOM', 'Turk Telekominasyon A.Ş.', '6.67')
# ('5', 'BIMAS', 'Bim Birleşik Mağazalar A.Ş.', '64.7')
# ('6', 'CCOLA', 'Coca Cola İçecek A.Ş.', '82.95')
# ('7', 'THYAO', 'Turk Hava Yolları A.O.', '12.99')
# ('8', 'VESTL', 'Vestel Elektronik Sanayi ve Ticaret A.Ş.', '29.1')
# ('9', 'PGSUS', 'Pegasus Hava Taşımacılığı A.Ş.', '81.35')
# ('10', 'ULKER', 'Ülker Bisküvi Sanayi A.Ş.', '22.46')
# ('11', 'GC1!', 'Altın Vadelileri', '15083.5')
# ('12', 'SI1!', 'Gümüş Vadelileri', '226.3')
# ('13', 'NG1!', 'Doğal Gaz Vadelileri', '24.36')
# ('14', 'CL1!', 'Hafif Ham Petrol Vadelileri', '534.55')
# ('15', 'USD', 'Dollar', '8.2')

# %%
insert_accountasset = (
    "INSERT INTO ACCOUNTASSETS(Asset_ID, A_ID, amount) "
    "VALUES (%s, %s, %s)"
)
populate_table(db_connection, db_cursor, insert_accountasset, "excels/AccountAssets.csv")
# Out:
# ('4', '2488', '51')
# ('2', '2489', '39')
# ('1', '2490', '23')
# ('1', '2491', '56')
# ('3', '2492', '19')
# ('4', '2493', '4')
# ('5', '2494', '53')
# ('2', '2495', '52')
# ('3', '2496', '62')
# ('3', '2497', '81')
# ('2', '2498', '30')
# ('3', '2499', '59')
# ('2', '2500', '6')
# ('4', '2501', '59')
# ('2', '2502', '94')
# ('1', '2503', '14')
# ('1', '2504', '52')
# ('5', '2505', '87')
# ('1', '2506', '85')
# ('3', '2507', '18')
# ('4', '2508', '23')
# ('4', '2509', '89')
# ('1', '2510', '88')
# ('3', '2511', '6')
# ('2', '2512', '30')
# ('5', '2513', '52')
# ('2', '2514', '22')
# ('4', '2515', '4')
# ('5', '2516', '68')
# ('4', '2517', '55')
# ('5', '2518', '61')
# ('2', '2519', '43')
# ('1', '2520', '74')
# ('1', '2521', '66')
# ('5', '2522', '45')
# ('2', '2523', '4')
# ('2', '2524', '28')
# ('5', '2525', '24')
# ('3', '2526', '66')
# ('4', '2527', '74')
# ('2', '2528', '80')
# ('5', '2529', '35')
# ('5', '2530', '29')
# ('4', '2531', '32')
# ('3', '2532', '43')
# ...

# %%
insert_transaction = (
    "INSERT INTO TRANSACTIONS(Transaction_ID, T_Date, Reciving_ID, Sending_ID, Explanation) "
    "VALUES (%s, %s, %s, %s, %s)"
)
populate_table(db_connection, db_cursor, insert_transaction, "excels/Transaction.csv")
# Out:
# ('1', '1990-7-13', '2521', '2493', 'Trade')
# ('2', '1990-7-15', '2535', '2555', 'Trade')
# ('3', '1990-9-26', '2543', '2536', 'Trade')
# ('4', '1990-10-30', '2560', '2493', 'Trade')
# ('5', '1991-1-10', '2599', '2555', 'Trade')
# ('6', '1991-1-11', '2579', '2584', 'Trade')
# ('7', '1991-1-28', '2514', '2543', 'Trade')
# ('8', '1991-1-29', '2512', '2522', 'Trade')
# ('9', '1991-1-30', '2525', '2576', 'Trade')
# ('10', '1991-3-4', '2519', '2531', 'Trade')
# ('11', '1991-3-5', '2535', '2548', 'Trade')
# ('12', '1991-4-21', '2572', '2520', 'Trade')
# ('13', '1991-4-28', '2512', '2582', 'Trade')
# ('14', '1991-5-7', '2501', '2549', 'Trade')
# ('15', '1991-5-12', '2506', '2590', 'Trade')
# ('16', '1991-6-21', '2552', '2508', 'Trade')
# ('17', '1991-8-4', '2582', '2556', 'Trade')
# ('18', '1991-9-2', '2561', '2520', 'Trade')
# ('19', '1992-3-5', '2519', '2594', 'Trade')
# ('20', '1992-3-9', '2499', '2584', 'Trade')
# ('21', '1992-5-17', '2542', '2575', 'Trade')
# ...

# %%
insert_Rtransaction = (
    "INSERT INTO R_TRANSACTION(Transaction_ID, R_Type, Amount, Currency) "
    "VALUES (%s, %s, %s, %s)"
)
populate_table(db_connection, db_cursor, insert_Rtransaction, "excels/R_Transaction.csv")
# Out:
# ('337', 'Deposit', '384746.25', 'TL')
# ('338', 'Deposit', '708353.25', 'TL')
# ('339', 'Deposit', '291479.25', 'TL')
# ('340', 'Deposit', '713584.5', 'TL')
# ('341', 'Deposit', '304781.25', 'TL')
# ('342', 'Deposit', '183979.5', 'TL')
# ('343', 'Deposit', '120130.5', 'TL')
# ('344', 'Deposit', '270429.75', 'TL')
# ('345', 'Deposit', '611901.75', 'TL')
# ('346', 'Deposit', '499364.25', 'TL')
# ('347', 'Deposit', '506032.5', 'TL')
# ('348', 'Deposit', '362154', 'TL')
# ('349', 'Deposit', '395202', 'TL')
# ('350', 'Deposit', '261182.25', 'TL')
# ('351', 'Deposit', '395629.5', 'TL')
# ('352', 'Deposit', '27298.5', 'TL')
# ('353', 'Deposit', '237526.5', 'TL')
# ('354', 'Deposit', '663375', 'TL')
# ('355', 'Deposit', '57195.75', 'TL')
# ('356', 'Deposit', '399005.25', 'TL')
# ('357', 'Deposit', '68688', 'TL')
# ('358', 'Deposit', '34224.75', 'TL')
# ('359', 'Deposit', '615016.5', 'TL')
# ('360', 'Deposit', '749216.25', 'TL')
# ('361', 'Deposit', '26420.25', 'TL')
# ...

# %%
insert_Ttransaction = (
    "INSERT INTO T_TRANSACTION(Transaction_ID, Asset_ID, Count) "
    "VALUES (%s, %s, %s)"
)
populate_table(db_connection, db_cursor, insert_Ttransaction, "excels/T_Transaction.csv")
# Out:
# ('1', '15', '39755')
# ('2', '15', '96559')
# ('3', '9', '15')
# ('4', '7', '24')
# ('5', '1', '51')
# ('6', '14', '81')
# ('7', '2', '22')
# ('8', '2', '30')
# ('9', '5', '24')
# ('10', '11', '79')
# ('11', '2', '36')
# ('12', '15', '93268')
# ('13', '7', '50')
# ('14', '4', '59')
# ('15', '13', '78')
# ('16', '15', '75333')
# ('17', '13', '13')
# ('18', '1', '65')
# ('19', '2', '43')
# ('20', '13', '75')
# ('21', '14', '98')
# ('22', '11', '65')
# ('23', '9', '41')
# ('24', '2', '81')
# ('25', '15', '11889')
# ('26', '4', '37')
# ('27', '14', '28')
# ('28', '7', '57')
# ('29', '15', '62897')
# ('30', '9', '80')
# ('31', '13', '51')
# ('32', '8', '58')
# ('33', '14', '15')
# ('34', '5', '69')
# ('35', '5', '98')
# ('36', '15', '76528')
# ('37', '6', '8')
# ('38', '9', '96')
# ('39', '5', '16')
# ('40', '13', '62')
# ('41', '9', '58')
# ('42', '10', '85')
# ('43', '5', '53')
# ('44', '2', '30')
# ('45', '5', '35')
# ('46', '15', '40339')
# ('47', '6', '88')
# ('48', '7', '22')
# ...
